# %% [markdown]
# # Sydney Livability Group Assignment

# %% [markdown]
# ## Marking Rubric
# - Data Import (0.5) : all 5 provided and linked files loaded
# - DB Schema (1.5): good normalised schema with al PKs and suitable FKs, consistent naming and suitable domain types (data is interpreted correctly, dates aren't read as strings etc.)
# - Neighbourhood Join (2): correct precise matching use PostGis and exact ABS boundaries
# - Own Dataset (2): Two or more extra datasets imported into DBMS with good schema of a type not used so far (e.g. JSON) and at least one spatial.
# - Livability Score (3): Livability score well implemented for both Greater Sydney adn City of Sydney, including extension of own datasets were integrated.
# - Indexing (1): more than one useful index created; at least one spatial index.
# - Correlation Tests (1): score correlated to BOTH median income and median rent prices
# - Dataset Description (1): all data sources briefly described
# - Database Description (1) : db schema diagram given
# - Liveability Analysis (1) : scoring function well described; good discusion of results ideally with graphical visualisation.
# - Correlation analysis (1.5) : correlation analysis described with statistical interpretation
# - Data Visualisation (2): good figures/plots plus some useful map-overlay visualisation (optional: even interactive)
# - Report Quality (1.5): great report which is in length limit, well structured, well written, no spelling mistakes and grammatically correct, good use of figures to visualise points, good font size and sapcing.
# - City of Syney Stakeholder Analysis (1 > 0): Proposed a stakeholder, a brief introduction and showed how you tailored your score for their needs. Results suitable visualised on a map.

# %% [markdown]
# ## To Do:
# - Clean tables. Make sure data is valid for when we upload it to the Sydney_Livability schema.
# - Figure out how to upload the zipped folders of data (non-csv data) into the notebook.
# - Identify the Primary and Foreign Keys for each table.
# - Upload the tables into the schema.
# - Figure out how to share the schema. Something to do with adding other peoples credentials into the credentials.json folder.
# - Identify other databases we want to use from the website provided.
# - Identify other stakeholders
# - Canvas "Quiz" on stakeholders and additional data: due Week 11 Friday.

# %% [markdown]
# ## Notes
# Accessing a PostgreSQL database within Python requires psycopg2 and sqlalchemy modules.
# Also require pandas.
# You need a crednetials.json file in the same folder to store database credentials. This will also allow us to share notebooks between users without security concerns and allow multiple credentials to be stored without greatly modifying the notebook.
# We have to use the public schema as it is the only schema with PostGis installed. We do not create our own schema. Will try to figure out how to share tables on a public schema.
# This code is from the Week 4 Tutorial

# %% [markdown]
# ## Connect to the database:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import MetaData


import psycopg2
import psycopg2.extras
import json
import os

credentials = "Credentials.json"

def pgconnect(credential_filepath, db_schema="public"):
    with open(credential_filepath) as f:
        db_conn_dict = json.load(f)
        host       = db_conn_dict['host']
        db_user    = db_conn_dict['user']
        db_pw      = db_conn_dict['password']
        default_db = db_conn_dict['user']
        try:
            db = create_engine('postgresql+psycopg2://'+db_user+':'+db_pw+'@'+host+'/'+default_db, echo=False)
            conn = db.connect()
            print('Connected successfully.')
        except Exception as e:
            print("Unable to connect to the database.")
            print(e)
            db, conn = None, None
        return db,conn

# %%
db, conn = pgconnect(credentials)
# Out:
# Connected successfully.

# %%
conn.close()

# %% [markdown]
# ## Exploring the Schema on PGAdmin:

# %%
from sqlalchemy import inspect
inspect(db).get_schema_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: connection to server at "soitpw11d59.shared.sydney.edu.au" (10.87.14.236), port 5432 failed: FATAL:  too many connections for database "y22s1d2x01_igro0534"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /var/folders/_y/lf_zrwbn3136_y2yw8d5lrm00000gn/T/ipykernel_30568/900568580.py in <module>
#       1 from sqlalchemy import inspect
# ----> 2 inspect(db).get_schema_names()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2067             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2068         elif should_wrap:
# -> 2069             util.raise_(
#    2070                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2071             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in connect(self)
#     305
#     306         """
# --> 307         return _ConnectionFairy._checkout(self)
#     308
#     309     def _return_conn(self, record):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     765     def _checkout(cls, pool, threadconns=None, fairy=None):
#     766         if not fairy:
# --> 767             fairy = _ConnectionRecord.checkout(pool)
#     768
#     769             fairy._pool = pool
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     423     @classmethod
#     424     def checkout(cls, pool):
# --> 425         rec = pool._do_get()
#     426         try:
#     427             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     251         """Called by subclasses to create a new ConnectionRecord."""
#     252
# --> 253         return _ConnectionRecord(self)
#     254
#     255     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     366         self.__pool = pool
#     367         if connect:
# --> 368             self.__connect()
#     369         self.finalize_callback = deque()
#     370
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     609         except Exception as e:
#     610             with util.safe_reraise():
# --> 611                 pool.logger.debug("Error on connect(): %s", e)
#     612         else:
#     613             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     603         try:
#     604             self.starttime = time.time()
# --> 605             connection = pool._invoke_creator(self)
#     606             pool.logger.debug("Created new connection %r", connection)
#     607             self.connection = connection
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "soitpw11d59.shared.sydney.edu.au" (10.87.14.236), port 5432 failed: FATAL:  too many connections for database "y22s1d2x01_igro0534"
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# Inspect a specific schema:

# %%
inspect(db).get_table_names(schema='nswfuel')
inspect(db).get_columns('observations', schema='nswfuel')
# Out:
# [{'name': 'servicestation',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'observationno',
#   'type': INTEGER(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'pricedate',
#   'type': DATE(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'pricetime',
#   'type': TIME(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None}]

# %% [markdown]
# ## Create a new schema!

# %% [markdown]
# This will set all of the queries you execute to look at the sydney_livability schema. Probably won't return anything useful until you have a sydney_livability schema in your PGAdmin Server. First need to figure out how to share a server with others.

# %%
conn.execute("set search_path to public")

# %% [markdown]
# Defining helper function: Query

# %%
def query(conn, sqlcmd, args=None, df=True):
    result = pd.DataFrame() if df else None
    try:
        if df:
            result = pd.read_sql_query(sqlcmd, conn, params=args)
        else:
            result = conn.execute(sqlcmd, args).fetchall()
            result = result[0] if len(result) == 1 else result
    except Exception as e:
        print("Error encountered: ", e, sep='\n')
    return result

# %%
# To switch off converting everything into a pandas dataframe use df = False like so:
# query(conn, "select count(*) from Fuel", df=False)

# %% [markdown]
# ## Exploring tables provided

# %%
nhdata = pd.read_csv('Neighbourhoods.csv')
nhdata.head(50)
# Out:
#     Unnamed: 0    area_id                            area_name  land_area  \
# 0            0  102011028             Avoca Beach - Copacabana      643.8
# 1            1  102011029          Box Head - MacMasters Beach     3208.6
# 2            2  102011030                      Calga - Kulnura    76795.1
# 3            3  102011031                  Erina - Green Point     3379.3
# 4            4  102011032                Gosford - Springfield     1691.2
# 5            5  102011033                              Kariong      830.6
# 6            6  102011034          Kincumber - Picketts Valley     1208.9
# 7            7  102011035                               Narara      770.2
# 8            8  102011036               Niagara Park - Lisarow     1673.2
# 9            9  102011037              Point Clare - Koolewong      678.7
# 10          10  102011038                 Saratoga - Davistown      476.8
# 11          11  102011039               Terrigal - North Avoca     1010.7
# 12          12  102011040         Umina - Booker Bay - Patonga     2522.8
# 13          13  102011041          Wamberal - Forresters Beach     1372.2
# 14          14  102011042                  Woy Woy - Blackwall     1742.3
# 15          15  102011043                              Wyoming      838.1
# 16          16  102021044          Bateau Bay - Killarney Vale     1086.0
# 17          17  102021045                Blue Haven - San Remo     2098.0
# 18          18  102021046   Budgewoi - Buff Point - Halekulani      935.3
# 19          19  102021047           Chittaway Bay - Tumbi Umbi     2449.9
# 20          20  102021048        Gorokan - Kanwal - Charmhaven     1124.9
# 21          21  102021049                Jilliby - Yarramalong    34676.6
# 22          22  102021050       Lake Munmorah - Mannering Park     3549.5
# 23          23  102021051              Ourimbah - Fountaindale    11411.7
# 24          24  102021052         Summerland Point - Gwandalan      917.9
# 25          25  102021053                         The Entrance     1385.8
# 26          26  102021054                 Toukley - Norah Head     1052.2
# 27          27  102021055                Tuggerah - Kangy Angy     2784.6
# 28          28  102021056                 Warnervale - Wadalba     4289.0
# 29          29  102021057                                Wyong     1503.3
# 30          30  115011290                Baulkham Hills (East)      830.8
# 31          31  115011291  Baulkham Hills (West) - Bella Vista     1096.3
# 32          32  115011294                            Glenhaven      723.1
# 33          33  115011296                   West Pennant Hills      782.9
# 34          34  115011553                Castle Hill - Central      415.1
# 35          35  115011554                   Castle Hill - East      207.2
# 36          36  115011555                  Castle Hill - North      681.5
# 37          37  115011556                  Castle Hill - South      412.8
# 38          38  115011557                   Castle Hill - West      163.6
# 39          39  115011558                          Cherrybrook      825.1
# 40          40  115011559                           Kellyville     1064.1
# 41          41  115021297   Dural - Kenthurst - Wisemans Ferry    37754.0
# 42          42  115021298               Galston - Laughtondale    19169.9
# 43          43  115031299            Bilpin - Colo - St Albans   216016.0
# 44          44  115031300         Kurrajong Heights - Ebenezer    33185.0
# 45          45  115041301            Pitt Town - McGraths Hill     8155.2
# 46          46  115041302          Rouse Hill - Beaumont Hills     3667.3
# 47          47  116011303        Blacktown (East) - Kings Park      797.5
# 48          48  116011304         Blacktown (North) - Marayong      738.3
# 49          49  116011306                 Doonside - Woodcroft      991.1
#
#    population number_of_dwellings  number_of_businesses  \
# 0        7590                2325                 738.0
# 1       10986                3847                 907.0
# 2        4841                1575                1102.0
# 3       14237                4450                1666.0
# 4       19385                6373                2126.0
# 5        6540                1824                 352.0
# 6        7428                1946                 479.0
# 7        6853                2006                 292.0
# 8        8173                2345                 477.0
# 9        6281                2220                 312.0
# 10       7177                2366                 486.0
# 11      14048                4457                1351.0
# 12      24251                7540                1217.0
# 13      10308                2947                 924.0
# 14      14327                4304                 691.0
# 15      11659                3269                 486.0
# 16      22465                6941                1035.0
# 17      11366                3624                 290.0
# 18       9639                3648                 350.0
# 19      15697                4947                 994.0
# 20      22567                7562                 816.0
# 21       3520                 973                 390.0
# 22      11093                4252                 424.0
# 23       4996                1317                 439.0
# 24       5904                2143                 287.0
# 25      15416                4428                1000.0
# 26      10092                3208                 588.0
# 27       5480                1420                 973.0
# 28      16365                4387                 768.0
# 29       9114                2805                 645.0
# 30      24370                6258                1880.0
# 31      21416                5244                4674.0
# 32       6467                1687                 736.0
# 33      13244                3543                1503.0
# 34       7992                2236                1803.0
# 35       5685                1489                 389.0
# 36      12409                3296                1347.0
# 37       9970                2774                1169.0
# 38       5368                1315                 520.0
# 39      19518                4862                1526.0
# 40      25111                6122                1856.0
# 41      22060                5920                3683.0
# 42       5378                1569                 816.0
# 43       2751                 858                 325.0
# 44      22443                6680                2430.0
# 45      11034                3083                1622.0
# 46      24977                5400                2154.0
# 47      17868                5044                2319.0
# 48      18984                4913                 867.0
# 49      24242                5920                 978.0
#
#     median_annual_household_income  avg_monthly_rent   0-4   5-9  10-14  15-19
# 0                          46996.0            1906.0   467   583    604    560
# 1                          42621.0            1682.0   586   696    661    692
# 2                          42105.0            1182.0   220   254    304    320
# 3                          43481.0            1595.0   695   778    916    838
# 4                          45972.0            1382.0  1200  1079    963    977
# 5                          47896.0            1649.0   472   502    497    591
# 6                          41642.0            1397.0   404   458    448    416
# 7                          46660.0            1512.0   463   470    448    459
# 8                          45762.0            1495.0   525   605    617    606
# 9                          45966.0            1572.0   371   412    373    343
# 10                         43171.0            1667.0   498   479    442    419
# 11                         46422.0            2022.0   816   860    828    873
# 12                         40252.0            1517.0  1410  1405   1218   1221
# 13                         47295.0            1902.0   691   803    730    655
# 14                         42481.0            1387.0   784   759    681    737
# 15                         43438.0            1466.0   721   764    675    724
# 16                         42469.0            1423.0  1490  1528   1321   1345
# 17                         42641.0            1526.0   900   939    879    912
# 18                         41702.0            1347.0   590   570    541    509
# 19                         45015.0            1593.0   993  1133   1046   1050
# 20                         41051.0            1330.0  1328  1390   1422   1401
# 21                         44122.0            1364.0   198   207    259    292
# 22                         41152.0            1363.0   583   619    587    612
# 23                         48214.0            1469.0   286   373    368    341
# 24                         42683.0            1455.0   324   368    390    355
# 25                         44137.0            1404.0   870   846    760    769
# 26                         39615.0            1296.0   586   530    459    479
# 27                         44360.0            1699.0   394   386    384    384
# 28                         47983.0            1823.0  1192  1411   1339   1161
# 29                         41055.0            1276.0   590   592    605    582
# 30                         52019.0            2166.0  1849  1908   1462   1245
# 31                         53703.0            2521.0  1236  1511   1370   1583
# 32                         50112.0            2661.0   307   429    452    446
# 33                         53907.0            2605.0   693   838    813   1003
# 34                         50992.0            2360.0   582   574    503    484
# 35                         48100.0            2088.0   192   338    314    386
# 36                         52307.0            2519.0   624   863    929    888
# 37                         52563.0            2387.0   666   759    660    621
# 38                         58568.0            2828.0   302   442    427    458
# 39                         50744.0            2756.0   850  1240   1504   1642
# 40                         55461.0            2681.0  1669  2011   2030   1813
# 41                         48550.0            1972.0  1124  1438   1611   1690
# 42                         45128.0            1897.0   250   346    408    363
# 43                         40176.0             906.0   141   143    180    152
# 44                         49194.0            1619.0  1413  1547   1680   1661
# 45                         50076.0            1793.0   774   857    740    795
# 46                         56607.0            2605.0  1731  2207   2124   1862
# 47                         45814.0            1587.0  1685  1117    781    871
# 48                         45946.0            1493.0  1421  1323   1121   1123
# 49                         49909.0            1371.0  1680  1710   1521   1678

# %%
business_stats_data = pd.read_csv('BusinessStats.csv')
business_stats_data.head(50)
# Out:
#       area_id                           area_name  number_of_businesses  \
# 0   101021007                           Braidwood                   629
# 1   101021008                             Karabar                   326
# 2   101021009                          Queanbeyan                   724
# 3   101021010                   Queanbeyan - East                   580
# 4   101021011                   Queanbeyan Region                  1642
# 5   101021012     Queanbeyan West - Jerrabomberra                   885
# 6   101031013                             Bombala                   419
# 7   101031014                               Cooma                   714
# 8   101031015                        Cooma Region                   478
# 9   101031016               Jindabyne - Berridale                  1032
# 10  101041017                        Batemans Bay                   692
# 11  101041018                Batemans Bay - South                   512
# 12  101041019                       Bega - Tathra                   768
# 13  101041020                Bega-Eden Hinterland                   860
# 14  101041021                   Broulee - Tomakin                   240
# 15  101041022                   Deua - Wadbilliga                     3
# 16  101041023                                Eden                   257
# 17  101041024              Eurobodalla Hinterland                   336
# 18  101041025              Merimbula - Tura Beach                   997
# 19  101041026                Moruya - Tuross Head                   645
# 20  101041027                  Narooma - Bermagui                   720
# 21  101051539                            Goulburn                  1528
# 22  101051540                     Goulburn Region                  1891
# 23  101061541                                Yass                   600
# 24  101061542                         Yass Region                  1732
# 25  101061543                               Young                  1142
# 26  101061544                        Young Region                  1074
# 27  102011028            Avoca Beach - Copacabana                   724
# 28  102011029         Box Head - MacMasters Beach                   934
# 29  102011030                     Calga - Kulnura                  1134
# 30  102011031                 Erina - Green Point                  1712
# 31  102011032               Gosford - Springfield                  2233
# 32  102011033                             Kariong                   351
# 33  102011034         Kincumber - Picketts Valley                   514
# 34  102011035                              Narara                   281
# 35  102011036              Niagara Park - Lisarow                   470
# 36  102011037             Point Clare - Koolewong                   343
# 37  102011038                Saratoga - Davistown                   515
# 38  102011039              Terrigal - North Avoca                  1419
# 39  102011040        Umina - Booker Bay - Patonga                  1243
# 40  102011041         Wamberal - Forresters Beach                   966
# 41  102011042                 Woy Woy - Blackwall                   709
# 42  102011043                             Wyoming                   505
# 43  102021044         Bateau Bay - Killarney Vale                  1065
# 44  102021045               Blue Haven - San Remo                   308
# 45  102021046  Budgewoi - Buff Point - Halekulani                   389
# 46  102021047          Chittaway Bay - Tumbi Umbi                  1047
# 47  102021048       Gorokan - Kanwal - Charmhaven                   822
# 48  102021049               Jilliby - Yarramalong                   392
# 49  102021050      Lake Munmorah - Mannering Park                   488
#
#     accommodation_and_food_services  retail_trade  \
# 0                                26            27
# 1                                 7            10
# 2                                52            47
# 3                                16            23
# 4                                39            63
# 5                                14            48
# 6                                18            14
# 7                                55            47
# 8                                11            15
# 9                               144            59
# 10                               62            75
# 11                               29            40
# 12                               42            75
# 13                               33            34
# 14                               18            12
# 15                                0             0
# 16                               25            16
# 17                               24            25
# 18                               99            89
# 19                               44            52
# 20                               70            65
# 21                               76           129
# 22                               38            52
# 23                               25            45
# 24                               40            52
# 25                               29            85
# 26                               28            29
# 27                               33            35
# 28                               23            45
# 29                               14            43
# 30                               68           145
# 31                               94           167
# 32                               17            18
# 33                               25            33
# 34                                5            13
# 35                               13            19
# 36                                8            18
# 37                               20            26
# 38                               71            79
# 39                               70            62
# 40                               31            42
# 41                               61            58
# 42                               22            33
# 43                               37            49
# 44                               13            10
# 45                               16            21
# 46                               26            54
# 47                               46            70
# 48                                8            14
# 49                               16            26
#
#     agriculture_forestry_and_fishing  health_care_and_social_assistance  \
# 0                                280                                 11
# 1                                  8                                 11
# 2                                 11                                 56
# 3                                  4                                 12
# 4                                292                                 34
# 5                                 14                                 29
# 6                                250                                  9
# 7                                110                                 36
# 8                                258                                  5
# 9                                161                                 43
# 10                                29                                 32
# 11                                16                                 38
# 12                                97                                 56
# 13                               336                                 22
# 14                                14                                 11
# 15                                 0                                  0
# 16                                44                                  8
# 17                                73                                  5
# 18                                66                                 61
# 19                                48                                 53
# 20                                71                                 26
# 21                               158                                 89
# 22                              1041                                 33
# 23                               148                                 19
# 24                               706                                 37
# 25                               312                                 38
# 26                               605                                 15
# 27                                 4                                 60
# 28                                13                                 43
# 29                               231                                 12
# 30                                19                                179
# 31                                 9                                246
# 32                                 0                                 14
# 33                                10                                 49
# 34                                 0                                 13
# 35                                 0                                 23
# 36                                 3                                 30
# 37                                12                                 21
# 38                                16                                163
# 39                                16                                 63
# 40                                13                                 87
# 41                                 7                                 37
# 42                                 3                                 48
# 43                                 8                                 52
# 44                                 4                                 13
# 45                                 0                                 12
# 46                                13                                 49
# 47                                 5                                 52
# 48                                49                                 12
# 49                                 9                                 17
#
#     public_administration_and_safety  transport_postal_and_warehousing
# 0                                  0                                35
# 1                                  0                                43
# 2                                  3                                77
# 3                                  0                                57
# 4                                  7                                81
# 5                                  3                                59
# 6                                  0                                14
# 7                                  0                                49
# 8                                  0                                26
# 9                                  3                                27
# 10                                 3                                34
# 11                                 0                                20
# 12                                 3                                37
# 13                                 0                                43
# 14                                 0                                 5
# 15                                 0                                 0
# 16                                 0                                12
# 17                                 0                                15
# 18                                 5                                46
# 19                                 0                                36
# 20                                 0                                29
# 21                                 4                                97
# 22                                 3                                81
# 23                                 0                                38
# 24                                 3                                58
# 25                                 5                                61
# 26                                 0                                60
# 27                                 0                                19
# 28                                 3                                28
# 29                                 0                                55
# 30                                12                                43
# 31                                10                                97
# 32                                 3                                27
# 33                                 5                                26
# 34                                 3                                20
# 35                                 0                                30
# 36                                 0                                20
# 37                                 0                                17
# 38                                 5                                48
# 39                                 0                                89
# 40                                 5                                37
# 41                                 3                                34
# 42                                 3                                30
# 43                                 8                                57
# 44                                 5                                29
# 45                                 0                                24
# 46                                 5                                70
# 47                                 5                                69
# 48                                 3                                22
# 49                                 0                                29

# %% [markdown]
# ## Clean data provided
# - Check for 0 or negative values
# - Check for null values
# - Check pandas is interpreting columns as the correct data type e.g. date is not an integer or string, its a date type.
# - Type and name conversion
# - Filtering missing data
# - Unifying semantic representations
# - Matching of entries
# - Handling of dates and time

# %% [markdown]
# ## Load data into new database:

# %%
# Create the Neighbourhoods table:

# conn.execute("""
# DROP TABLE IF EXISTS Neighbourhoods;
# CREATE TABLE Neighbourhoods(
#     area_id INTEGER NOT NULL PRIMARY KEY,
#     area_name VARCHAR(50),
#     land_area FLOAT8,
#     population INTEGER,
#     number_of_dwellings INTEGER,
#     number_of_businesses FLOAT8,
#     median_annual_household_income FLOAT8,
#     avg_monthly_rent FLOAT8,
#     child0_4 INTEGER,
#     child5_9 INTEGER,
#     child10_14 INTEGER,
#     child15_19 INTEGER
#     )""")

# %%
# DO NOT RUN YET. FIRST MUST CLEAN THE DATA SO IT WILL UPLOAD CORRECTLY. 
# nhdata.to_sql("neighbourhoods", con=conn, if_exists='append', index=False)
# query(conn, "select * from neighbourhoods")

# %%
# Create the BusinessStats table:

# conn.execute("""
# DROP TABLE IF EXISTS BusinessStats
# CREATE TABLE BusinessStats(
#     area_id INTEGER NOT NULL REFERENCES BusinessStats(area_id),
#     area_name VARCHAR(50) PRIMARY KEY,
#     number_of_businesses INTEGER,
#     accommodation_and_food_services INTEGER,
#     retail_trade INTEGER,
#     agriculture_forestry_and_fishing INTEGER,
#     health_care_and_social_assistance INTEGER,
#     public_administration_and_safety INTEGER,
#     transport_postal_and_warehousing INTEGER
    
#     )""")

# %%
# DO NOT RUN YET. FIRST MUST CLEAN THE DATA SO IT WILL UPLOAD CORRECTLY. 
# business_stats.to_sql("business_stats", con=conn, if_exists='append', index=False)
# query(conn, "select * from business_stats")

# %%
# Create the SA2_2016_AUST table:

# conn.execute("""
# DROP TABLE IF EXISTS SA2_2016_AUST;
# CREATE TABLE SA2_2016_AUST(
#     SA2_MAIN16 INTEGER NOT NULL PRIMARY KEY,
#     SA2_NAME16 VARCHAR(50) NOT NULL REFERENCES BusinessStats(area_name),
#     SA3_CODE16 INTEGER,
#     SA3_NAME16 VARCHAR(50),
#     STE_CODE16 INTEGER,
#     STE_CODE16 VARCHAR(50),
#     AREASQKM16 FLOAT,
#     geometry GEOMETRY(MULTIPOLYGON,4326)
#     
#     )""")

# %%
# DO NOT RUN YET. FIRST MUST CLEAN THE DATA SO IT WILL UPLOAD CORRECTLY. 
# SA2_2016_AUST.to_sql("SA2_2016_Aust", con=conn, if_exists='append', index=False)
# query(conn, "select * from SA2_2016_Aust")

# %%
# Repeat for break and enter, school chatchments, and the two extra datasets.

# %%
# CODE TO DELETE TABLE:
# conn.execute("""
# DROP TABLE IF EXISTS neighbourhoods;
# """)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_y/lf_zrwbn3136_y2yw8d5lrm00000gn/T/ipykernel_30568/3886047035.py in <module>
# ----> 1 conn.close()
#
# AttributeError: 'NoneType' object has no attribute 'close'

# %% [markdown]
# ## Loading GeoData

# %%
# Installing the relevant packages
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon, MultiPolygon
from geoalchemy2 import Geometry, WKTElement
import matplotlib.pyplot as plt

# %%
break_enter = gpd.read_file("break_and_enter/BreakEnterDwelling_JanToDec2021.shp")
break_enter
# Out:
#       OBJECTID  Contour       Density  ORIG_FID  Shape_Leng  Shape_Area  \
# 0            1      8.0   Low Density         1    0.012138    0.000006
# 1            2      8.0   Low Density         1    0.019106    0.000015
# 2            3      8.0   Low Density         1    0.006068    0.000002
# 3            4      8.0   Low Density         1    0.011006    0.000006
# 4            5      8.0   Low Density         1    0.008073    0.000003
# ...        ...      ...           ...       ...         ...         ...
# 2589      2590     10.0  High Density         3    0.015358    0.000011
# 2590      2591     10.0  High Density         3    0.028327    0.000029
# 2591      2592     10.0  High Density         3    0.006654    0.000002
# 2592      2593     10.0  High Density         3    0.047098    0.000044
# 2593      2594     10.0  High Density         3    0.016336    0.000014
#
#                                                geometry
# 0     POLYGON ((149.91078 -37.06636, 149.91080 -37.0...
# 1     POLYGON ((149.90601 -37.05837, 149.90602 -37.0...
# 2     POLYGON ((148.94250 -37.04209, 148.94253 -37.0...
# 3     POLYGON ((149.19583 -36.91833, 149.19584 -36.9...
# 4     POLYGON ((149.84836 -36.68459, 149.84838 -36.6...
# ...                                                 ...
# 2589  POLYGON ((153.27961 -28.55388, 153.27964 -28.5...
# 2590  POLYGON ((150.35939 -28.60530, 150.35941 -28.6...
# 2591  POLYGON ((153.56825 -28.38307, 153.56828 -28.3...
# 2592  POLYGON ((153.53917 -28.18858, 153.53920 -28.1...
# 2593  POLYGON ((153.54243 -28.16992, 153.54246 -28.1...
#
# [2594 rows x 7 columns]

# %%
SA2 = gpd.read_file("SA2_2016_Aust/SA2_2016_AUST.shp")
SA2.head(50)
SA2.tail(50)
# Out:
#      SA2_MAIN16 SA2_5DIG16                             SA2_NAME16 SA3_CODE16  \
# 2260  801071079      81079                           Gowrie (ACT)      80107
# 2261  801071080      81080                               Greenway      80107
# 2262  801071081      81081                        Isabella Plains      80107
# 2263  801071082      81082                                 Kambah      80107
# 2264  801071083      81083                              Macarthur      80107
# 2265  801071084      81084                                 Monash      80107
# 2266  801071085      81085                           Mount Taylor      80107
# 2267  801071086      81086                            Oxley (ACT)      80107
# 2268  801071087      81087                             Richardson      80107
# 2269  801071088      81088                               Theodore      80107
# 2270  801071089      81089                            Tuggeranong      80107
# 2271  801071090      81090                              Wanniassa      80107
# 2272  801071132      81132                     Tuggeranong - West      80107
# 2273  801081091      81091                                Chapman      80108
# 2274  801081092      81092                                  Duffy      80108
# 2275  801081093      81093                                 Fisher      80108
# 2276  801081094      81094                                 Holder      80108
# 2277  801081095      81095                                 Rivett      80108
# 2278  801081096      81096                               Stirling      80108
# 2279  801081097      81097                              Waramanga      80108
# 2280  801081098      81098                                 Weston      80108
# 2281  801081133      81133                              Scrivener      80108
# 2282  801091099      81099                                Chifley      80109
# 2283  801091100      81100                                 Curtin      80109
# 2284  801091101      81101                                 Farrer      80109
# 2285  801091102      81102                                 Garran      80109
# 2286  801091103      81103                                 Hughes      80109
# 2287  801091104      81104                                 Isaacs      80109
# 2288  801091105      81105                            Lyons (ACT)      80109
# 2289  801091106      81106                                 Mawson      80109
# 2290  801091107      81107                               O'Malley      80109
# 2291  801091108      81108                                 Pearce      80109
# 2292  801091109      81109                                Phillip      80109
# 2293  801091110      81110                                Torrens      80109
# 2294  801101134      81134                              Arboretum      80110
# 2295  801101135      81135                                 Coombs      80110
# 2296  801101136      81136                        Denman Prospect      80110
# 2297  801101137      81137                               Molonglo      80110
# 2298  801101138      81138                       Molonglo - North      80110
# 2299  801101139      81139                                 Wright      80110
# 2300  801111140      81140                       ACT - South West      80111
# 2301  801111141      81141                                Namadgi      80111
# 2302  897979799      89799  Migratory - Offshore - Shipping (ACT)      89797
# 2303  899999499      89499                 No usual address (ACT)      89999
# 2304  901011001      91001                       Christmas Island      90101
# 2305  901021002      91002                Cocos (Keeling) Islands      90102
# 2306  901031003      91003                             Jervis Bay      90103
# 2307  901041004      91004                         Norfolk Island      90104
# 2308  997979799      99799   Migratory - Offshore - Shipping (OT)      99797
# 2309  999999499      99499                  No usual address (OT)      99999
#
#                                  SA3_NAME16 SA4_CODE16  \
# 2260                            Tuggeranong        801
# 2261                            Tuggeranong        801
# 2262                            Tuggeranong        801
# 2263                            Tuggeranong        801
# 2264                            Tuggeranong        801
# 2265                            Tuggeranong        801
# 2266                            Tuggeranong        801
# 2267                            Tuggeranong        801
# 2268                            Tuggeranong        801
# 2269                            Tuggeranong        801
# 2270                            Tuggeranong        801
# 2271                            Tuggeranong        801
# 2272                            Tuggeranong        801
# 2273                           Weston Creek        801
# 2274                           Weston Creek        801
# 2275                           Weston Creek        801
# 2276                           Weston Creek        801
# 2277                           Weston Creek        801
# 2278                           Weston Creek        801
# 2279                           Weston Creek        801
# 2280                           Weston Creek        801
# 2281                           Weston Creek        801
# 2282                           Woden Valley        801
# 2283                           Woden Valley        801
# 2284                           Woden Valley        801
# 2285                           Woden Valley        801
# 2286                           Woden Valley        801
# 2287                           Woden Valley        801
# 2288                           Woden Valley        801
# 2289                           Woden Valley        801
# 2290                           Woden Valley        801
# 2291                           Woden Valley        801
# 2292                           Woden Valley        801
# 2293                           Woden Valley        801
# 2294                               Molonglo        801
# 2295                               Molonglo        801
# 2296                               Molonglo        801
# 2297                               Molonglo        801
# 2298                               Molonglo        801
# 2299                               Molonglo        801
# 2300                     Urriarra - Namadgi        801
# 2301                     Urriarra - Namadgi        801
# 2302  Migratory - Offshore - Shipping (ACT)        897
# 2303                 No usual address (ACT)        899
# 2304                       Christmas Island        901
# 2305                Cocos (Keeling) Islands        901
# 2306                             Jervis Bay        901
# 2307                         Norfolk Island        901
# 2308   Migratory - Offshore - Shipping (OT)        997
# 2309                  No usual address (OT)        999
#
#                                  SA4_NAME16 GCC_CODE16  \
# 2305  MULTIPOLYGON (((96.83047 -12.17636, 96.83045 -...
# 2306  MULTIPOLYGON (((150.69566 -35.18297, 150.69555...
# 2307  MULTIPOLYGON (((167.99472 -29.04534, 167.99432...
# 2308                                               None
# 2309                                               None

# %%
school_catchments_future = gpd.read_file("school_catchments/catchments_future.shp")
school_catchments_primary = gpd.read_file("school_catchments/catchments_primary.shp")
school_catchments_secondary = gpd.read_file("school_catchments/catchments_secondary.shp")
school_catchments_future
school_catchments_primary
school_catchments_secondary
# Out:
#     USE_ID    CATCH_TYPE             USE_DESC  ADD_DATE KINDERGART YEAR1  \
# 0     8503     HIGH_COED         Billabong HS  20200507          N     N
# 1     8266     HIGH_COED      James Fallon HS  20200507          N     N
# 2     8505     HIGH_COED            Murray HS  20200507          N     N
# 3     8246     HIGH_COED         Heathcote HS      None          N     N
# 4     8458     HIGH_COED         Kingswood HS  20201016          N     N
# ..     ...           ...                  ...       ...        ...   ...
# 430   8213     HIGH_BOYS          Birrong BHS  20211221          N     N
# 431   8857    HIGH_GIRLS  GRC Penshurst Girls  20220110          N     N
# 432   3235  CENTRAL_HIGH         Tooleybuc CS  20200512          N     N
# 433   1115  CENTRAL_HIGH         Balranald CS  20200512          N     N
# 434   2213  CENTRAL_HIGH           Ivanhoe CS  20200512          N     N
#
#     YEAR2 YEAR3 YEAR4 YEAR5 YEAR6 YEAR7 YEAR8 YEAR9 YEAR10 YEAR11 YEAR12  \
# 0       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 1       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 2       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 3       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 4       N     N     N     N     N     Y     Y     Y      Y      Y      Y
# ..    ...   ...   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 430     N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 431     N     N     N     N     N     Y     Y     Y      Y      N      N
# 432     N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 433     N     N     N     N     N     Y     Y     Y      Y      Y      Y
# 434     N     N     N     N     N     Y     Y     Y      Y      Y      Y
#
#     PRIORITY                                           geometry
# 0       None  POLYGON ((146.67182 -35.31444, 146.68930 -35.3...
# 1       None  POLYGON ((147.08734 -35.86271, 147.10413 -35.8...
# 2       None  POLYGON ((146.81448 -35.78341, 146.81250 -35.7...
# 3       None  POLYGON ((151.03281 -34.02521, 151.03267 -34.0...
# 4       None  MULTIPOLYGON (((150.68600 -33.74031, 150.68631...
# ..       ...                                                ...
# 430     None  POLYGON ((151.05364 -33.85076, 151.06142 -33.8...
# 431     None  POLYGON ((151.07573 -33.95089, 151.07921 -33.9...
# 432     None  POLYGON ((143.37723 -34.80173, 143.39037 -34.8...
# 433     None  POLYGON ((143.65541 -33.55702, 143.65541 -33.5...
# 434     None  POLYGON ((144.31579 -32.17239, 144.32923 -32.1...
#
# [435 rows x 19 columns]

# %%
# To convert longitdue and latitude into points example from tutorial:
# cities['geom'] = gpd.points_from_xy(cities.lng, cities.lat)  # creating the geometry column
# cities = cities.drop(columns=['lat', 'lng'])  # removing the old latitude/longitude fields

# %% [markdown]
# ## Format of the Schema (Primary & Foreign Keys)
#
# BusinessStats(area_id) <-> Neighbourhoods(area_id)
# BusinessStats(area_name) <-> SA2(SA2_NAME16)
# SA2(geometry) <-> break_enter(geometry)
# school_catchments(geometry) <-> SA2(geometry)
